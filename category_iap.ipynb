# %%
import pandas as pd
import numpy as np
import datetime

# %%
df2 = pd.read_csv("/Users/leon.zhao/Desktop/py/category_iap.csv")
pd.to_datetime(df2.MIN_TS)
pd.to_datetime(df2.HEADER_TIMESTAMP)

# %%
df2.head()
# Out:
#                           MIN_TS               HEADER_TIMESTAMP  \
# 0  2018-11-16 06:57:47.070 +0000  2018-12-04 20:32:13.020 +0000
# 1  2018-11-09 19:40:17.970 +0000  2018-11-13 00:43:09.914 +0000
# 2  2018-11-09 19:40:17.970 +0000  2018-12-03 17:18:21.521 +0000
# 3  2018-11-03 11:52:31.525 +0000  2018-11-07 00:54:58.786 +0000
# 4  2018-11-03 11:52:31.525 +0000  2018-11-07 00:56:45.928 +0000
#
#           TREATMENT  HEADER_USER_ID  BUMPERS  SELLER_AD_PURCHASERS  \
# 0       lowCategory        15039335        0                     1
# 1  extraLowCategory          820322        0                     1
# 2  extraLowCategory          820322        0                     1
# 3  extraLowCategory        20761424        1                     0
# 4  extraLowCategory        20761424        1                     0
#
#    IN_APP_PURCHASERS  FREE_TRIAL_SUBSCRIBERS  PAID_SUBSCRIBERS  BUMP_REVENUE  \
# 0                  1                       0                 0          0.00
# ...

# %%
date = pd.to_datetime('2018-01-01')
for i in range(10):
    print(date)
# Out:
# 2018-01-01 00:00:00
# 2018-01-01 00:00:00
# 2018-01-01 00:00:00
# 2018-01-01 00:00:00
# 2018-01-01 00:00:00
# 2018-01-01 00:00:00
# 2018-01-01 00:00:00
# 2018-01-01 00:00:00
# 2018-01-01 00:00:00
# 2018-01-01 00:00:00

# %%
start = datetime.datetime.strptime("2018-01-01", "%Y-%m-%d")
date_list = [start + datetime.timedelta(days=x) for x in range(0, 365)]

# %%
for date in date_list:
    print(date.strftime("%Y-%m-%d"))
# Out:
# 2018-01-01
# 2018-01-02
# 2018-01-03
# 2018-01-04
# 2018-01-05
# 2018-01-06
# 2018-01-07
# 2018-01-08
# 2018-01-09
# 2018-01-10
# 2018-01-11
# 2018-01-12
# 2018-01-13
# 2018-01-14
# 2018-01-15
# 2018-01-16
# 2018-01-17
# 2018-01-18
# 2018-01-19
# 2018-01-20
# 2018-01-21
# 2018-01-22
# 2018-01-23
# 2018-01-24
# 2018-01-25
# 2018-01-26
# 2018-01-27
# 2018-01-28
# 2018-01-29
# 2018-01-30
# 2018-01-31
# 2018-02-01
# 2018-02-02
# 2018-02-03
# 2018-02-04
# 2018-02-05
# 2018-02-06
# 2018-02-07
# 2018-02-08
# 2018-02-09
# 2018-02-10
# 2018-02-11
# 2018-02-12
# 2018-02-13
# 2018-02-14
# 2018-02-15
# 2018-02-16
# 2018-02-17
# 2018-02-18
# 2018-02-19
# 2018-02-20
# 2018-02-21
# 2018-02-22
# 2018-02-23
# 2018-02-24
# 2018-02-25
# 2018-02-26
# 2018-02-27
# 2018-02-28
# 2018-03-01
# 2018-03-02
# 2018-03-03
# 2018-03-04
# 2018-03-05
# 2018-03-06
# 2018-03-07
# 2018-03-08
# 2018-03-09
# 2018-03-10
# 2018-03-11
# 2018-03-12
# 2018-03-13
# 2018-03-14
# 2018-03-15
# 2018-03-16
# 2018-03-17
# ...
